# %%
import os

# %%
cd ~/Desktop/DICOM/
# Out:
# /Users/yn_mbp/Desktop/DICOM
# /Users/yn_mbp/yn_venv/lib/python3.9/site-packages/IPython/core/magics/osm.py:393: UserWarning: using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})
# /Users/yn_mbp/yn_venv/lib/python3.9/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
dir = [d for d in os.listdir() if os.path.isdir(os.path.join(".", d))]
dir
# Out:
# ['L1283576_20240731',
#  'L9746875_20240611',
#  'L8297604_20240624',
#  'L3059775_20240617',
#  'L2072205_20240527',
#  'L6346636_20240613',
#  'L8825076_20240611',
#  'L0607966_20240625',
#  'L1889853_20240610',
#  'L2951036_20240624',
#  'Ltest_20240528',
#  'Ltest_ny_20240607',
#  'L2282936_20240605',
#  'L1945276_20240529',
#  'L3397176_20240621',
#  'L5616822_20240528',
#  'L7256576_20240702',
#  'L4864576_20240704',
#  'L1326446_20240701',
#  'L2934965_20240710']

# %%
for i in dir:
    os.chdir(f"./{i}")
    # !python3 ~/git/yn-scripts/nrrd2dcm.py Na_correct_v4.nrrd 03 corrected
    os.chdir("..")
# Out:
# /Users/yn_mbp/yn_venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Saved: corrected/00001.dcm
# Saved: corrected/00002.dcm
# Saved: corrected/00003.dcm
# Saved: corrected/00004.dcm
# Saved: corrected/00005.dcm
# Saved: corrected/00006.dcm
# Saved: corrected/00007.dcm
# Saved: corrected/00008.dcm
# Saved: corrected/00009.dcm
# Saved: corrected/00010.dcm
# Saved: corrected/00011.dcm
# Saved: corrected/00012.dcm
# Saved: corrected/00013.dcm
# Saved: corrected/00014.dcm
# Saved: corrected/00015.dcm
# Saved: corrected/00016.dcm
# Saved: corrected/00017.dcm
# Saved: corrected/00018.dcm
# Saved: corrected/00019.dcm
# Saved: corrected/00020.dcm
# Saved: corrected/00021.dcm
# Saved: corrected/00022.dcm
# Saved: corrected/00023.dcm
# Saved: corrected/00024.dcm
# Saved: corrected/00025.dcm
# Saved: corrected/00026.dcm
# Saved: corrected/00027.dcm
# Saved: corrected/00028.dcm
# /Users/yn_mbp/yn_venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Saved: corrected/00001.dcm
# Saved: corrected/00002.dcm
# Saved: corrected/00003.dcm
# Saved: corrected/00004.dcm
# Saved: corrected/00005.dcm
# Saved: corrected/00006.dcm
# Saved: corrected/00007.dcm
# Saved: corrected/00008.dcm
# Saved: corrected/00009.dcm
# Saved: corrected/00010.dcm
# Saved: corrected/00011.dcm
# Saved: corrected/00012.dcm
# Saved: corrected/00013.dcm
# Saved: corrected/00014.dcm
# Saved: corrected/00015.dcm
# Saved: corrected/00016.dcm
# Saved: corrected/00017.dcm
# Saved: corrected/00018.dcm
# Saved: corrected/00019.dcm
# Saved: corrected/00020.dcm
# Saved: corrected/00021.dcm
# Saved: corrected/00022.dcm
# Saved: corrected/00023.dcm
# Saved: corrected/00024.dcm
# Saved: corrected/00025.dcm
# Saved: corrected/00026.dcm
# Saved: corrected/00027.dcm
# Saved: corrected/00028.dcm
# /Users/yn_mbp/yn_venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Saved: corrected/00001.dcm
# Saved: corrected/00002.dcm
# Saved: corrected/00003.dcm
# Saved: corrected/00004.dcm
# Saved: corrected/00005.dcm
# Saved: corrected/00006.dcm
# Saved: corrected/00007.dcm
# Saved: corrected/00008.dcm
# Saved: corrected/00009.dcm
# Saved: corrected/00010.dcm
# Saved: corrected/00011.dcm
# Saved: corrected/00012.dcm
# Saved: corrected/00013.dcm
# Saved: corrected/00014.dcm
# Saved: corrected/00015.dcm
# Saved: corrected/00016.dcm
# Saved: corrected/00017.dcm
# Saved: corrected/00018.dcm
# Saved: corrected/00019.dcm
# Saved: corrected/00020.dcm
# Saved: corrected/00021.dcm
# Saved: corrected/00022.dcm
# Saved: corrected/00023.dcm
# Saved: corrected/00024.dcm
# Saved: corrected/00025.dcm
# Saved: corrected/00026.dcm
# Saved: corrected/00027.dcm
# Saved: corrected/00028.dcm
# /Users/yn_mbp/yn_venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Saved: corrected/00001.dcm
# Saved: corrected/00002.dcm
# Saved: corrected/00003.dcm
# Saved: corrected/00004.dcm
# Saved: corrected/00005.dcm
# Saved: corrected/00006.dcm
# Saved: corrected/00007.dcm
# Saved: corrected/00008.dcm
# Saved: corrected/00009.dcm
# Saved: corrected/00010.dcm
# Saved: corrected/00011.dcm
# Saved: corrected/00012.dcm
# Saved: corrected/00013.dcm
# Saved: corrected/00014.dcm
# Saved: corrected/00015.dcm
# Saved: corrected/00016.dcm
# Saved: corrected/00017.dcm
# Saved: corrected/00018.dcm
# Saved: corrected/00019.dcm
# Saved: corrected/00020.dcm
# Saved: corrected/00021.dcm
# Saved: corrected/00022.dcm
# Saved: corrected/00023.dcm
# Saved: corrected/00024.dcm
# Saved: corrected/00025.dcm
# Saved: corrected/00026.dcm
# Saved: corrected/00027.dcm
# Saved: corrected/00028.dcm
# /Users/yn_mbp/yn_venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Saved: corrected/00001.dcm
# Saved: corrected/00002.dcm
# Saved: corrected/00003.dcm
# Saved: corrected/00004.dcm
# Saved: corrected/00005.dcm
# Saved: corrected/00006.dcm
# Saved: corrected/00007.dcm
# Saved: corrected/00008.dcm
# Saved: corrected/00009.dcm
# Saved: corrected/00010.dcm
# Saved: corrected/00011.dcm
# Saved: corrected/00012.dcm
# Saved: corrected/00013.dcm
# Saved: corrected/00014.dcm
# Saved: corrected/00015.dcm
# Saved: corrected/00016.dcm
# Saved: corrected/00017.dcm
# Saved: corrected/00018.dcm
# Saved: corrected/00019.dcm
# Saved: corrected/00020.dcm
# Saved: corrected/00021.dcm
# Saved: corrected/00022.dcm
# Saved: corrected/00023.dcm
# Saved: corrected/00024.dcm
# Saved: corrected/00025.dcm
# Saved: corrected/00026.dcm
# Saved: corrected/00027.dcm
# Saved: corrected/00028.dcm
# /Users/yn_mbp/yn_venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Saved: corrected/00001.dcm
# Saved: corrected/00002.dcm
# Saved: corrected/00003.dcm
# Saved: corrected/00004.dcm
# Saved: corrected/00005.dcm
# Saved: corrected/00006.dcm
# Saved: corrected/00007.dcm
# Saved: corrected/00008.dcm
# Saved: corrected/00009.dcm
# Saved: corrected/00010.dcm
# Saved: corrected/00011.dcm
# Saved: corrected/00012.dcm
# Saved: corrected/00013.dcm
# Saved: corrected/00014.dcm
# Saved: corrected/00015.dcm
# Saved: corrected/00016.dcm
# Saved: corrected/00017.dcm
# Saved: corrected/00018.dcm
# Saved: corrected/00019.dcm
# Saved: corrected/00020.dcm
# Saved: corrected/00021.dcm
# Saved: corrected/00022.dcm
# Saved: corrected/00023.dcm
# Saved: corrected/00024.dcm
# Saved: corrected/00025.dcm
# Saved: corrected/00026.dcm
# Saved: corrected/00027.dcm
# Saved: corrected/00028.dcm
# /Users/yn_mbp/yn_venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Saved: corrected/00001.dcm
# Saved: corrected/00002.dcm
# Saved: corrected/00003.dcm
# Saved: corrected/00004.dcm
# Saved: corrected/00005.dcm
# Saved: corrected/00006.dcm
# Saved: corrected/00007.dcm
# Saved: corrected/00008.dcm
# Saved: corrected/00009.dcm
# Saved: corrected/00010.dcm
# Saved: corrected/00011.dcm
# Saved: corrected/00012.dcm
# Saved: corrected/00013.dcm
# Saved: corrected/00014.dcm
# Saved: corrected/00015.dcm
# Saved: corrected/00016.dcm
# Saved: corrected/00017.dcm
# Saved: corrected/00018.dcm
# Saved: corrected/00019.dcm
# Saved: corrected/00020.dcm
# Saved: corrected/00021.dcm
# Saved: corrected/00022.dcm
# Saved: corrected/00023.dcm
# Saved: corrected/00024.dcm
# Saved: corrected/00025.dcm
# Saved: corrected/00026.dcm
# Saved: corrected/00027.dcm
# Saved: corrected/00028.dcm
# /Users/yn_mbp/yn_venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Saved: corrected/00001.dcm
# Saved: corrected/00002.dcm
# Saved: corrected/00003.dcm
# Saved: corrected/00004.dcm
# Saved: corrected/00005.dcm
# Saved: corrected/00006.dcm
# Saved: corrected/00007.dcm
# Saved: corrected/00008.dcm
# Saved: corrected/00009.dcm
# Saved: corrected/00010.dcm
# Saved: corrected/00011.dcm
# Saved: corrected/00012.dcm
# Saved: corrected/00013.dcm
# Saved: corrected/00014.dcm
# Saved: corrected/00015.dcm
# Saved: corrected/00016.dcm
# Saved: corrected/00017.dcm
# Saved: corrected/00018.dcm
# Saved: corrected/00019.dcm
# Saved: corrected/00020.dcm
# Saved: corrected/00021.dcm
# Saved: corrected/00022.dcm
# Saved: corrected/00023.dcm
# Saved: corrected/00024.dcm
# Saved: corrected/00025.dcm
# Saved: corrected/00026.dcm
# Saved: corrected/00027.dcm
# Saved: corrected/00028.dcm
# /Users/yn_mbp/yn_venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Saved: corrected/00001.dcm
# Saved: corrected/00002.dcm
# Saved: corrected/00003.dcm
# Saved: corrected/00004.dcm
# Saved: corrected/00005.dcm
# Saved: corrected/00006.dcm
# Saved: corrected/00007.dcm
# Saved: corrected/00008.dcm
# Saved: corrected/00009.dcm
# Saved: corrected/00010.dcm
# Saved: corrected/00011.dcm
# Saved: corrected/00012.dcm
# Saved: corrected/00013.dcm
# Saved: corrected/00014.dcm
# Saved: corrected/00015.dcm
# Saved: corrected/00016.dcm
# Saved: corrected/00017.dcm
# Saved: corrected/00018.dcm
# Saved: corrected/00019.dcm
# Saved: corrected/00020.dcm
# Saved: corrected/00021.dcm
# Saved: corrected/00022.dcm
# Saved: corrected/00023.dcm
# Saved: corrected/00024.dcm
# Saved: corrected/00025.dcm
# Saved: corrected/00026.dcm
# Saved: corrected/00027.dcm
# Saved: corrected/00028.dcm
# /Users/yn_mbp/yn_venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Saved: corrected/00001.dcm
# Saved: corrected/00002.dcm
# Saved: corrected/00003.dcm
# Saved: corrected/00004.dcm
# Saved: corrected/00005.dcm
# Saved: corrected/00006.dcm
# Saved: corrected/00007.dcm
# Saved: corrected/00008.dcm
# Saved: corrected/00009.dcm
# Saved: corrected/00010.dcm
# Saved: corrected/00011.dcm
# Saved: corrected/00012.dcm
# Saved: corrected/00013.dcm
# Saved: corrected/00014.dcm
# Saved: corrected/00015.dcm
# Saved: corrected/00016.dcm
# Saved: corrected/00017.dcm
# Saved: corrected/00018.dcm
# Saved: corrected/00019.dcm
# Saved: corrected/00020.dcm
# Saved: corrected/00021.dcm
# Saved: corrected/00022.dcm
# Saved: corrected/00023.dcm
# Saved: corrected/00024.dcm
# Saved: corrected/00025.dcm
# Saved: corrected/00026.dcm
# Saved: corrected/00027.dcm
# Saved: corrected/00028.dcm
# /Users/yn_mbp/yn_venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Saved: corrected/00001.dcm
# Saved: corrected/00002.dcm
# Saved: corrected/00003.dcm
# Saved: corrected/00004.dcm
# Saved: corrected/00005.dcm
# Saved: corrected/00006.dcm
# Saved: corrected/00007.dcm
# Saved: corrected/00008.dcm
# Saved: corrected/00009.dcm
# Saved: corrected/00010.dcm
# Saved: corrected/00011.dcm
# Saved: corrected/00012.dcm
# Saved: corrected/00013.dcm
# Saved: corrected/00014.dcm
# Saved: corrected/00015.dcm
# Saved: corrected/00016.dcm
# Saved: corrected/00017.dcm
# Saved: corrected/00018.dcm
# Saved: corrected/00019.dcm
# Saved: corrected/00020.dcm
# Saved: corrected/00021.dcm
# Saved: corrected/00022.dcm
# Saved: corrected/00023.dcm
# Saved: corrected/00024.dcm
# Saved: corrected/00025.dcm
# Saved: corrected/00026.dcm
# Saved: corrected/00027.dcm
# Saved: corrected/00028.dcm
# /Users/yn_mbp/yn_venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Saved: corrected/00001.dcm
# Saved: corrected/00002.dcm
# Saved: corrected/00003.dcm
# Saved: corrected/00004.dcm
# Saved: corrected/00005.dcm
# Saved: corrected/00006.dcm
# Saved: corrected/00007.dcm
# Saved: corrected/00008.dcm
# Saved: corrected/00009.dcm
# Saved: corrected/00010.dcm
# Saved: corrected/00011.dcm
# Saved: corrected/00012.dcm
# Saved: corrected/00013.dcm
# Saved: corrected/00014.dcm
# Saved: corrected/00015.dcm
# Saved: corrected/00016.dcm
# Saved: corrected/00017.dcm
# Saved: corrected/00018.dcm
# Saved: corrected/00019.dcm
# Saved: corrected/00020.dcm
# Saved: corrected/00021.dcm
# Saved: corrected/00022.dcm
# Saved: corrected/00023.dcm
# Saved: corrected/00024.dcm
# Saved: corrected/00025.dcm
# Saved: corrected/00026.dcm
# Saved: corrected/00027.dcm
# Saved: corrected/00028.dcm
# /Users/yn_mbp/yn_venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Saved: corrected/00001.dcm
# Saved: corrected/00002.dcm
# Saved: corrected/00003.dcm
# Saved: corrected/00004.dcm
# Saved: corrected/00005.dcm
# Saved: corrected/00006.dcm
# Saved: corrected/00007.dcm
# Saved: corrected/00008.dcm
# Saved: corrected/00009.dcm
# Saved: corrected/00010.dcm
# Saved: corrected/00011.dcm
# Saved: corrected/00012.dcm
# Saved: corrected/00013.dcm
# Saved: corrected/00014.dcm
# Saved: corrected/00015.dcm
# Saved: corrected/00016.dcm
# Saved: corrected/00017.dcm
# Saved: corrected/00018.dcm
# Saved: corrected/00019.dcm
# Saved: corrected/00020.dcm
# Saved: corrected/00021.dcm
# Saved: corrected/00022.dcm
# Saved: corrected/00023.dcm
# Saved: corrected/00024.dcm
# Saved: corrected/00025.dcm
# Saved: corrected/00026.dcm
# Saved: corrected/00027.dcm
# Saved: corrected/00028.dcm
# /Users/yn_mbp/yn_venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Saved: corrected/00001.dcm
# Saved: corrected/00002.dcm
# Saved: corrected/00003.dcm
# Saved: corrected/00004.dcm
# Saved: corrected/00005.dcm
# Saved: corrected/00006.dcm
# Saved: corrected/00007.dcm
# Saved: corrected/00008.dcm
# Saved: corrected/00009.dcm
# Saved: corrected/00010.dcm
# Saved: corrected/00011.dcm
# Saved: corrected/00012.dcm
# Saved: corrected/00013.dcm
# Saved: corrected/00014.dcm
# Saved: corrected/00015.dcm
# Saved: corrected/00016.dcm
# Saved: corrected/00017.dcm
# Saved: corrected/00018.dcm
# Saved: corrected/00019.dcm
# Saved: corrected/00020.dcm
# Saved: corrected/00021.dcm
# Saved: corrected/00022.dcm
# Saved: corrected/00023.dcm
# Saved: corrected/00024.dcm
# Saved: corrected/00025.dcm
# Saved: corrected/00026.dcm
# Saved: corrected/00027.dcm
# Saved: corrected/00028.dcm
# /Users/yn_mbp/yn_venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Saved: corrected/00001.dcm
# Saved: corrected/00002.dcm
# Saved: corrected/00003.dcm
# Saved: corrected/00004.dcm
# Saved: corrected/00005.dcm
# Saved: corrected/00006.dcm
# Saved: corrected/00007.dcm
# Saved: corrected/00008.dcm
# Saved: corrected/00009.dcm
# Saved: corrected/00010.dcm
# Saved: corrected/00011.dcm
# Saved: corrected/00012.dcm
# Saved: corrected/00013.dcm
# Saved: corrected/00014.dcm
# Saved: corrected/00015.dcm
# Saved: corrected/00016.dcm
# Saved: corrected/00017.dcm
# Saved: corrected/00018.dcm
# Saved: corrected/00019.dcm
# Saved: corrected/00020.dcm
# Saved: corrected/00021.dcm
# Saved: corrected/00022.dcm
# Saved: corrected/00023.dcm
# Saved: corrected/00024.dcm
# Saved: corrected/00025.dcm
# Saved: corrected/00026.dcm
# Saved: corrected/00027.dcm
# Saved: corrected/00028.dcm
# /Users/yn_mbp/yn_venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Saved: corrected/00001.dcm
# Saved: corrected/00002.dcm
# Saved: corrected/00003.dcm
# Saved: corrected/00004.dcm
# Saved: corrected/00005.dcm
# Saved: corrected/00006.dcm
# Saved: corrected/00007.dcm
# Saved: corrected/00008.dcm
# Saved: corrected/00009.dcm
# Saved: corrected/00010.dcm
# Saved: corrected/00011.dcm
# Saved: corrected/00012.dcm
# Saved: corrected/00013.dcm
# Saved: corrected/00014.dcm
# Saved: corrected/00015.dcm
# Saved: corrected/00016.dcm
# Saved: corrected/00017.dcm
# Saved: corrected/00018.dcm
# Saved: corrected/00019.dcm
# Saved: corrected/00020.dcm
# Saved: corrected/00021.dcm
# Saved: corrected/00022.dcm
# Saved: corrected/00023.dcm
# Saved: corrected/00024.dcm
# Saved: corrected/00025.dcm
# Saved: corrected/00026.dcm
# Saved: corrected/00027.dcm
# Saved: corrected/00028.dcm
# /Users/yn_mbp/yn_venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Saved: corrected/00001.dcm
# Saved: corrected/00002.dcm
# Saved: corrected/00003.dcm
# Saved: corrected/00004.dcm
# Saved: corrected/00005.dcm
# Saved: corrected/00006.dcm
# Saved: corrected/00007.dcm
# Saved: corrected/00008.dcm
# Saved: corrected/00009.dcm
# Saved: corrected/00010.dcm
# Saved: corrected/00011.dcm
# Saved: corrected/00012.dcm
# Saved: corrected/00013.dcm
# Saved: corrected/00014.dcm
# Saved: corrected/00015.dcm
# Saved: corrected/00016.dcm
# Saved: corrected/00017.dcm
# Saved: corrected/00018.dcm
# Saved: corrected/00019.dcm
# Saved: corrected/00020.dcm
# Saved: corrected/00021.dcm
# Saved: corrected/00022.dcm
# Saved: corrected/00023.dcm
# Saved: corrected/00024.dcm
# Saved: corrected/00025.dcm
# Saved: corrected/00026.dcm
# Saved: corrected/00027.dcm
# Saved: corrected/00028.dcm
# /Users/yn_mbp/yn_venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Saved: corrected/00001.dcm
# Saved: corrected/00002.dcm
# Saved: corrected/00003.dcm
# Saved: corrected/00004.dcm
# Saved: corrected/00005.dcm
# Saved: corrected/00006.dcm
# Saved: corrected/00007.dcm
# Saved: corrected/00008.dcm
# Saved: corrected/00009.dcm
# Saved: corrected/00010.dcm
# Saved: corrected/00011.dcm
# Saved: corrected/00012.dcm
# Saved: corrected/00013.dcm
# Saved: corrected/00014.dcm
# Saved: corrected/00015.dcm
# Saved: corrected/00016.dcm
# Saved: corrected/00017.dcm
# Saved: corrected/00018.dcm
# Saved: corrected/00019.dcm
# Saved: corrected/00020.dcm
# Saved: corrected/00021.dcm
# Saved: corrected/00022.dcm
# Saved: corrected/00023.dcm
# Saved: corrected/00024.dcm
# Saved: corrected/00025.dcm
# Saved: corrected/00026.dcm
# Saved: corrected/00027.dcm
# Saved: corrected/00028.dcm
# /Users/yn_mbp/yn_venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Saved: corrected/00001.dcm
# Saved: corrected/00002.dcm
# Saved: corrected/00003.dcm
# Saved: corrected/00004.dcm
# Saved: corrected/00005.dcm
# Saved: corrected/00006.dcm
# Saved: corrected/00007.dcm
# Saved: corrected/00008.dcm
# Saved: corrected/00009.dcm
# Saved: corrected/00010.dcm
# Saved: corrected/00011.dcm
# Saved: corrected/00012.dcm
# Saved: corrected/00013.dcm
# Saved: corrected/00014.dcm
# Saved: corrected/00015.dcm
# Saved: corrected/00016.dcm
# Saved: corrected/00017.dcm
# Saved: corrected/00018.dcm
# Saved: corrected/00019.dcm
# Saved: corrected/00020.dcm
# Saved: corrected/00021.dcm
# Saved: corrected/00022.dcm
# Saved: corrected/00023.dcm
# Saved: corrected/00024.dcm
# Saved: corrected/00025.dcm
# Saved: corrected/00026.dcm
# Saved: corrected/00027.dcm
# Saved: corrected/00028.dcm
# /Users/yn_mbp/yn_venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Saved: corrected/00001.dcm
# Saved: corrected/00002.dcm
# Saved: corrected/00003.dcm
# Saved: corrected/00004.dcm
# Saved: corrected/00005.dcm
# Saved: corrected/00006.dcm
# Saved: corrected/00007.dcm
# Saved: corrected/00008.dcm
# Saved: corrected/00009.dcm
# Saved: corrected/00010.dcm
# Saved: corrected/00011.dcm
# Saved: corrected/00012.dcm
# Saved: corrected/00013.dcm
# Saved: corrected/00014.dcm
# Saved: corrected/00015.dcm
# Saved: corrected/00016.dcm
# Saved: corrected/00017.dcm
# Saved: corrected/00018.dcm
# Saved: corrected/00019.dcm
# Saved: corrected/00020.dcm
# Saved: corrected/00021.dcm
# Saved: corrected/00022.dcm
# Saved: corrected/00023.dcm
# Saved: corrected/00024.dcm
# Saved: corrected/00025.dcm
# Saved: corrected/00026.dcm
# Saved: corrected/00027.dcm
# Saved: corrected/00028.dcm

# %%
# !python ~/git/yn-scripts/compare_metadata_dicom.py ./Ltest_ny_20240607/03/00005.dcm ./Ltest_ny_20240607/corrected/00005.dcm
# Out:
# /Users/yn_mbp/yn_venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/yn_mbp/yn_venv/lib/python3.9/site-packages/pydicom/valuerep.py:443: UserWarning: The value length (73) exceeds the maximum length of 64 allowed for VR UI. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warnings.warn(msg)
#           Tag  ...                                             File 2
# 0     2097166  ...  1.2.392.200036.9125.20035242211232065.65071655...
# 1      524312  ...  1.2.826.0.1.3680043.8.498.42990707199783044301...
# 2      528446  ...                                 Na_correct_v4.nrrd
# 3     1572944  ...                                           4.999998
# 4     2097169  ...                                                702
# 5     2621697  ...                                                 16
# 6     2621698  ...                                                 15
# 7  2145386512  ...  b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00...
#
# [8 rows x 4 columns]
